# %%
import sys

# %%
# !unzip fp
# Out:
# Archive:  fp.zip
#   inflating: run.py
#   inflating: .DS_Store
#   inflating: requirements.txt
#    creating: evaluation_results/
#    creating: evaluation_results/eval_results/
#    creating: evaluation_results/eval_results/eval_outputv0t50/
#    creating: evaluation_results/eval_results/eval_outputv0t50/runs/
#    creating: evaluation_results/eval_results/eval_outputv0t50/runs/Dec07_20-42-31_a262e9a27f3f/
#   inflating: evaluation_results/eval_results/eval_outputv0t50/runs/Dec07_20-42-31_a262e9a27f3f/events.out.tfevents.1701981775.a262e9a27f3f.91958.0
#   inflating: evaluation_results/eval_results/eval_outputv0t50/eval_predictions.jsonl
#   inflating: evaluation_results/eval_results/eval_outputv0t50/eval_metrics.json
#    creating: evaluation_results/eval_results/eval_outputv100t50/
#    creating: evaluation_results/eval_results/eval_outputv100t50/runs/
#    creating: evaluation_results/eval_results/eval_outputv100t50/runs/Dec07_20-34-12_a262e9a27f3f/
# ...

# %%
# !{sys.executable} -m pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 12.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 10.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 10.6 MB/s eta 0:00:00
# ...

# %%
# %cd /content/trained_model/
# Out:
# /content/trained_model

# %%
# %cd /content/trained_model90/
# Out:
# /content/trained_model90

# %%
# !rm -rf checkpoint-1000/
# !rm -rf checkpoint-1500/
# !rm -rf checkpoint-2000/
# !rm -rf checkpoint-2500/
# !rm -rf checkpoint-3000/
# !rm -rf checkpoint-3500/
# !rm -rf checkpoint-4000/
# !rm -rf checkpoint-4500/
# !rm -rf checkpoint-5000/
# !rm -rf checkpoint-5500/
# !rm -rf checkpoint-6000/
# !rm -rf checkpoint-6500/
# !rm -rf checkpoint-7000/
# !rm -rf checkpoint-7500/
# !rm -rf checkpoint-8000/
# !rm -rf checkpoint-8500/
# !rm -rf checkpoint-9000/
# !rm -rf checkpoint-9500/
# !rm -rf checkpoint-10000/
# !rm -rf checkpoint-10500/
# !rm -rf checkpoint-11000/
# !rm -rf checkpoint-11500/
# !rm -rf checkpoint-12000/
# !rm -rf checkpoint-12500/
# !rm -rf checkpoint-13000/
# !rm -rf checkpoint-13500/
# !rm -rf checkpoint-14000/
# !rm -rf checkpoint-14500/
# !rm -rf checkpoint-15000/
# !rm -rf checkpoint-15500/
# !rm -rf checkpoint-16000/
# !rm -rf checkpoint-16500/
# !rm -rf checkpoint-17000/
# !rm -rf checkpoint-17500/
# !rm -rf checkpoint-18000/
# !rm -rf checkpoint-18500/
# !rm -rf checkpoint-19000/
# !rm -rf checkpoint-19500/
# !rm -rf checkpoint-20000/
# !rm -rf checkpoint-20500/
# !rm -rf checkpoint-21000/
# !rm -rf checkpoint-21500/
# !rm -rf checkpoint-22000/
# !rm -rf checkpoint-22500/
# !rm -rf checkpoint-23000/
# !rm -rf checkpoint-23500/
# !rm -rf checkpoint-24000/
# !rm -rf checkpoint-24500/
# !rm -rf checkpoint-25000/
# !rm -rf checkpoint-25500/
# !rm -rf checkpoint-26000/
# !rm -rf checkpoint-26500/
# !rm -rf checkpoint-27000/
# !rm -rf checkpoint-27500/
# !rm -rf checkpoint-28000/
# !rm -rf checkpoint-28500/
# !rm -rf checkpoint-29000/
# !rm -rf checkpoint-29500/
# !rm -rf checkpoint-30000/
# !rm -rf checkpoint-30500/
# !rm -rf checkpoint-31000/
# !rm -rf checkpoint-31500/

# %%
# # # !python3 run.py --do_train --task qa --dataset datasets/train/dataset7525.jsonl --output_dir ./trained_model75/

# # !python3 run.py --do_train --task qa --dataset datasets/train/dataset1000.jsonl --output_dir ./trained_model100/
# # %cd /content/trained_model100/
# # !rm -rf checkpoint-500/
# # !rm -rf checkpoint-1000/
# # !rm -rf checkpoint-1500/
# # !rm -rf checkpoint-2000/
# # !rm -rf checkpoint-2500/
# # !rm -rf checkpoint-3000/
# # !rm -rf checkpoint-3500/
# # !rm -rf checkpoint-4000/
# # !rm -rf checkpoint-4500/
# # !rm -rf checkpoint-5000/
# # !rm -rf checkpoint-5500/
# # !rm -rf checkpoint-6000/
# # !rm -rf checkpoint-6500/
# # !rm -rf checkpoint-7000/
# # !rm -rf checkpoint-7500/
# # !rm -rf checkpoint-8000/
# # !rm -rf checkpoint-8500/
# # !rm -rf checkpoint-9000/
# # !rm -rf checkpoint-9500/
# # !rm -rf checkpoint-10000/
# # !rm -rf checkpoint-10500/
# # !rm -rf checkpoint-11000/
# # !rm -rf checkpoint-11500/
# # !rm -rf checkpoint-12000/
# # !rm -rf checkpoint-12500/
# # !rm -rf checkpoint-13000/
# # !rm -rf checkpoint-13500/
# # !rm -rf checkpoint-14000/
# # !rm -rf checkpoint-14500/
# # !rm -rf checkpoint-15000/
# # !rm -rf checkpoint-15500/
# # !rm -rf checkpoint-16000/
# # !rm -rf checkpoint-16500/
# # !rm -rf checkpoint-17000/
# # !rm -rf checkpoint-17500/
# # !rm -rf checkpoint-18000/
# # !rm -rf checkpoint-18500/
# # !rm -rf checkpoint-19000/
# # !rm -rf checkpoint-19500/
# # !rm -rf checkpoint-20000/
# # !rm -rf checkpoint-20500/
# # !rm -rf checkpoint-21000/
# # !rm -rf checkpoint-21500/
# # !rm -rf checkpoint-22000/
# # !rm -rf checkpoint-22500/
# # !rm -rf checkpoint-23000/
# # !rm -rf checkpoint-23500/
# # !rm -rf checkpoint-24000/
# # !rm -rf checkpoint-24500/
# # !rm -rf checkpoint-25000/
# # !rm -rf checkpoint-25500/
# # !rm -rf checkpoint-26000/
# # !rm -rf checkpoint-26500/
# # !rm -rf checkpoint-27000/
# # !rm -rf checkpoint-27500/
# # !rm -rf checkpoint-28000/
# # !rm -rf checkpoint-28500/
# # !rm -rf checkpoint-29000/
# # !rm -rf checkpoint-29500/
# # !rm -rf checkpoint-30000/
# # !rm -rf checkpoint-30500/
# # !rm -rf checkpoint-31000/
# # !rm -rf checkpoint-31500/
# # !zip -r /content/trained_model100.zip /content/trained_model100/

# # %cd /content/
# # !python3 run.py --do_train --task qa --dataset datasets/train/dataset9010.jsonl --output_dir ./trained_model90/
# # %cd /content/trained_model90/
# # !rm -rf checkpoint-500/
# # !rm -rf checkpoint-1000/
# # !rm -rf checkpoint-1500/
# # !rm -rf checkpoint-2000/
# # !rm -rf checkpoint-2500/
# # !rm -rf checkpoint-3000/
# # !rm -rf checkpoint-3500/
# # !rm -rf checkpoint-4000/
# # !rm -rf checkpoint-4500/
# # !rm -rf checkpoint-5000/
# # !rm -rf checkpoint-5500/
# # !rm -rf checkpoint-6000/
# # !rm -rf checkpoint-6500/
# # !rm -rf checkpoint-7000/
# # !rm -rf checkpoint-7500/
# # !rm -rf checkpoint-8000/
# # !rm -rf checkpoint-8500/
# # !rm -rf checkpoint-9000/
# # !rm -rf checkpoint-9500/
# # !rm -rf checkpoint-10000/
# # !rm -rf checkpoint-10500/
# # !rm -rf checkpoint-11000/
# # !rm -rf checkpoint-11500/
# # !rm -rf checkpoint-12000/
# # !rm -rf checkpoint-12500/
# # !rm -rf checkpoint-13000/
# # !rm -rf checkpoint-13500/
# # !rm -rf checkpoint-14000/
# # !rm -rf checkpoint-14500/
# # !rm -rf checkpoint-15000/
# # !rm -rf checkpoint-15500/
# # !rm -rf checkpoint-16000/
# # !rm -rf checkpoint-16500/
# # !rm -rf checkpoint-17000/
# # !rm -rf checkpoint-17500/
# # !rm -rf checkpoint-18000/
# # !rm -rf checkpoint-18500/
# # !rm -rf checkpoint-19000/
# # !rm -rf checkpoint-19500/
# # !rm -rf checkpoint-20000/
# # !rm -rf checkpoint-20500/
# # !rm -rf checkpoint-21000/
# # !rm -rf checkpoint-21500/
# # !rm -rf checkpoint-22000/
# # !rm -rf checkpoint-22500/
# # !rm -rf checkpoint-23000/
# # !rm -rf checkpoint-23500/
# # !rm -rf checkpoint-24000/
# # !rm -rf checkpoint-24500/
# # !rm -rf checkpoint-25000/
# # !rm -rf checkpoint-25500/
# # !rm -rf checkpoint-26000/
# # !rm -rf checkpoint-26500/
# # !rm -rf checkpoint-27000/
# # !rm -rf checkpoint-27500/
# # !rm -rf checkpoint-28000/
# # !rm -rf checkpoint-28500/
# # !rm -rf checkpoint-29000/
# # !rm -rf checkpoint-29500/
# # !rm -rf checkpoint-30000/
# # !rm -rf checkpoint-30500/
# # !rm -rf checkpoint-31000/
# # !rm -rf checkpoint-31500/
# # !zip -r /content/trained_model90.zip /content/trained_model90/

# %cd /content/
# !python3 run.py --do_train --task qa --dataset datasets/train/dataset7525.jsonl --output_dir ./trained_model75/
# %cd /content/trained_model75/
# !rm -rf checkpoint-500/
# !rm -rf checkpoint-1000/
# !rm -rf checkpoint-1500/
# !rm -rf checkpoint-2000/
# !rm -rf checkpoint-2500/
# !rm -rf checkpoint-3000/
# !rm -rf checkpoint-3500/
# !rm -rf checkpoint-4000/
# !rm -rf checkpoint-4500/
# !rm -rf checkpoint-5000/
# !rm -rf checkpoint-5500/
# !rm -rf checkpoint-6000/
# !rm -rf checkpoint-6500/
# !rm -rf checkpoint-7000/
# !rm -rf checkpoint-7500/
# !rm -rf checkpoint-8000/
# !rm -rf checkpoint-8500/
# !rm -rf checkpoint-9000/
# !rm -rf checkpoint-9500/
# !rm -rf checkpoint-10000/
# !rm -rf checkpoint-10500/
# !rm -rf checkpoint-11000/
# !rm -rf checkpoint-11500/
# !rm -rf checkpoint-12000/
# !rm -rf checkpoint-12500/
# !rm -rf checkpoint-13000/
# !rm -rf checkpoint-13500/
# !rm -rf checkpoint-14000/
# !rm -rf checkpoint-14500/
# !rm -rf checkpoint-15000/
# !rm -rf checkpoint-15500/
# !rm -rf checkpoint-16000/
# !rm -rf checkpoint-16500/
# !rm -rf checkpoint-17000/
# !rm -rf checkpoint-17500/
# !rm -rf checkpoint-18000/
# !rm -rf checkpoint-18500/
# !rm -rf checkpoint-19000/
# !rm -rf checkpoint-19500/
# !rm -rf checkpoint-20000/
# !rm -rf checkpoint-20500/
# !rm -rf checkpoint-21000/
# !rm -rf checkpoint-21500/
# !rm -rf checkpoint-22000/
# !rm -rf checkpoint-22500/
# !rm -rf checkpoint-23000/
# !rm -rf checkpoint-23500/
# !rm -rf checkpoint-24000/
# !rm -rf checkpoint-24500/
# !rm -rf checkpoint-25000/
# !rm -rf checkpoint-25500/
# !rm -rf checkpoint-26000/
# !rm -rf checkpoint-26500/
# !rm -rf checkpoint-27000/
# !rm -rf checkpoint-27500/
# !rm -rf checkpoint-28000/
# !rm -rf checkpoint-28500/
# !rm -rf checkpoint-29000/
# !rm -rf checkpoint-29500/
# !rm -rf checkpoint-30000/
# !rm -rf checkpoint-30500/
# !rm -rf checkpoint-31000/
# !rm -rf checkpoint-31500/
# !zip -r /content/trained_model75.zip /content/trained_model75/

# %%
# %pwd
# Out:
# '/content/trained_model'

# %%
# !zip -r /content/trained_model.zip /content/trained_model/
# Out:
# updating: content/trained_model/ (stored 0%)
#   adding: content/trained_model/training_args.bin (deflated 51%)
#   adding: content/trained_model/tokenizer.json (deflated 71%)
#   adding: content/trained_model/special_tokens_map.json (deflated 42%)
#   adding: content/trained_model/config.json (deflated 51%)
#   adding: content/trained_model/checkpoint-32000/ (stored 0%)
#   adding: content/trained_model/checkpoint-32000/training_args.bin (deflated 51%)
#   adding: content/trained_model/checkpoint-32000/tokenizer.json (deflated 71%)
#   adding: content/trained_model/checkpoint-32000/special_tokens_map.json (deflated 42%)
#   adding: content/trained_model/checkpoint-32000/config.json (deflated 51%)
#   adding: content/trained_model/checkpoint-32000/trainer_state.json (deflated 80%)
#   adding: content/trained_model/checkpoint-32000/model.safetensors (deflated 7%)
#   adding: content/trained_model/checkpoint-32000/optimizer.pt (deflated 12%)
# ...

# %%
# !du -sh /content/trained_model.zip
# Out:
# 326M	/content/trained_model.zip

# %%
# !zip -r /content/trained_model90.zip /content/trained_model90/
# Out:
#   adding: content/trained_model90/ (stored 0%)
#   adding: content/trained_model90/training_args.bin (deflated 51%)
#   adding: content/trained_model90/tokenizer.json (deflated 71%)
#   adding: content/trained_model90/checkpoint-500/ (stored 0%)
#   adding: content/trained_model90/checkpoint-500/training_args.bin (deflated 51%)
#   adding: content/trained_model90/checkpoint-500/tokenizer.json (deflated 71%)
#   adding: content/trained_model90/checkpoint-500/special_tokens_map.json (deflated 42%)
#   adding: content/trained_model90/checkpoint-500/config.json (deflated 51%)
#   adding: content/trained_model90/checkpoint-500/trainer_state.json (deflated 49%)
#   adding: content/trained_model90/checkpoint-500/model.safetensors (deflated 7%)
#   adding: content/trained_model90/checkpoint-500/optimizer.pt (deflated 15%)
#   adding: content/trained_model90/checkpoint-500/vocab.txt (deflated 53%)
#   adding: content/trained_model90/checkpoint-500/scheduler.pt (deflated 56%)
# ...

# %%
# %cd /content/
# !python3 run.py --do_eval --task qa --dataset datasets/validation/validation100.jsonl --model ./trained_model100/ --output_dir ./eval_results/eval_outputv100t100/
# !python3 run.py --do_eval --task qa --dataset datasets/validation/validation100.jsonl --model ./trained_model90/ --output_dir ./eval_results/eval_outputv100t90/
# !python3 run.py --do_eval --task qa --dataset datasets/validation/validation100.jsonl --model ./trained_model75/ --output_dir ./eval_results/eval_outputv100t75/
# !python3 run.py --do_eval --task qa --dataset datasets/validation/validation100.jsonl --model ./trained_model50/ --output_dir ./eval_results/eval_outputv100t50/

# !python3 run.py --do_eval --task qa --dataset datasets/validation/validation50.jsonl --model ./trained_model100/ --output_dir ./eval_results/eval_outputv50t100/
# !python3 run.py --do_eval --task qa --dataset datasets/validation/validation50.jsonl --model ./trained_model90/ --output_dir ./eval_results/eval_outputv50t90/
# !python3 run.py --do_eval --task qa --dataset datasets/validation/validation50.jsonl --model ./trained_model75/ --output_dir ./eval_results/eval_outputv50t75/
# !python3 run.py --do_eval --task qa --dataset datasets/validation/validation50.jsonl --model ./trained_model50/ --output_dir ./eval_results/eval_outputv50t50/

# !python3 run.py --do_eval --task qa --dataset datasets/validation/validation0.jsonl --model ./trained_model100/ --output_dir ./eval_results/eval_outputv0t100/
# !python3 run.py --do_eval --task qa --dataset datasets/validation/validation0.jsonl --model ./trained_model90/ --output_dir ./eval_results/eval_outputv0t90/
# !python3 run.py --do_eval --task qa --dataset datasets/validation/validation0.jsonl --model ./trained_model75/ --output_dir ./eval_results/eval_outputv0t75/
# !python3 run.py --do_eval --task qa --dataset datasets/validation/validation0.jsonl --model ./trained_model50/ --output_dir ./eval_results/eval_outputv0t50/
# Out:
# /content
# 2023-12-07 20:30:12.220683: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-07 20:30:12.220743: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-07 20:30:12.220769: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-07 20:30:13.436034: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Preprocessing data... (this takes a little bit, should only happen once per dataset)
# ...

# %%
"""
{'eval_exact_match': 78.39167455061495, 'eval_f1': 86.2008844284333}
{'eval_exact_match': 77.59697256385998, 'eval_f1': 85.62728496348102}
{'eval_exact_match': 77.52128666035951, 'eval_f1': 85.38521971299429}


{'eval_exact_match': 61.57048249763481, 'eval_f1': 69.99153474960937}
{'eval_exact_match': 62.28949858088931, 'eval_f1': 70.76662345336861}
{'eval_exact_match': 63.15988647114475, 'eval_f1': 71.52668669171256}


{'eval_exact_match': 18.7, 'eval_f1': 29.038267818287554}
{'eval_exact_match': 23.4, 'eval_f1': 33.51152323909096}
{'eval_exact_match': 26.166666666666668, 'eval_f1': 36.34177672546178}
{'eval_exact_match': 26.7, 'eval_f1': 36.955752011154715}

"""

# %%
# !unzip trained_model50
# !unzip trained_model75
# !unzip trained_model90
# !unzip trained_model100
# Out:
# Archive:  trained_model50.zip
#    creating: content/trained_model/
#   inflating: content/trained_model/training_args.bin
#   inflating: content/trained_model/tokenizer.json
#   inflating: content/trained_model/special_tokens_map.json
#   inflating: content/trained_model/config.json
#    creating: content/trained_model/checkpoint-32000/
#   inflating: content/trained_model/checkpoint-32000/training_args.bin
#   inflating: content/trained_model/checkpoint-32000/tokenizer.json
#   inflating: content/trained_model/checkpoint-32000/special_tokens_map.json
#   inflating: content/trained_model/checkpoint-32000/config.json
#   inflating: content/trained_model/checkpoint-32000/trainer_state.json
#   inflating: content/trained_model/checkpoint-32000/model.safetensors
#   inflating: content/trained_model/checkpoint-32000/optimizer.pt
#   inflating: content/trained_model/checkpoint-32000/vocab.txt
#   inflating: content/trained_model/checkpoint-32000/scheduler.pt
# ...

# %%
# !python3 run.py --do_eval --task qa --dataset squad_temp_checklist.json --model ./content/trained_model100/ --output_dir ./checklist_results/checklist100/
# !python3 run.py --do_eval --task qa --dataset squad_temp_checklist.json --model ./content/trained_model90/ --output_dir ./checklist_results/checklist90/
# !python3 run.py --do_eval --task qa --dataset squad_temp_checklist.json --model ./content/trained_model75/ --output_dir ./checklist_results/checklist75/
# !python3 run.py --do_eval --task qa --dataset squad_temp_checklist.json --model ./content/trained_model/ --output_dir ./eval_results/checklist50/
# Out:
# 2023-12-09 04:42:46.010564: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-09 04:42:46.010617: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-09 04:42:46.010645: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-09 04:42:47.258593: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
# Extracting data files: 100% 1/1 [00:00<00:00, 1605.17it/s]
# Generating train split: 90 examples [00:00, 4999.10 examples/s]
# Preprocessing data... (this takes a little bit, should only happen once per dataset)
# ...

# %%
# !python3 run.py --do_eval --task qa --dataset timepoint.json --model ./content/trained_model100/ --output_dir ./timepoint/checklist100/
# !python3 run.py --do_eval --task qa --dataset timepoint.json --model ./content/trained_model90/ --output_dir ./timepoint/checklist90/
# !python3 run.py --do_eval --task qa --dataset timepoint.json --model ./content/trained_model75/ --output_dir ./timepoint/checklist75/
# !python3 run.py --do_eval --task qa --dataset timepoint.json --model ./content/trained_model/ --output_dir ./timepoint/checklist50/
# Out:
# 2023-12-09 08:21:45.493991: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-09 08:21:45.494049: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-09 08:21:45.494078: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-09 08:21:46.782914: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
# Extracting data files: 100% 1/1 [00:00<00:00, 1455.34it/s]
# Generating train split: 10 examples [00:00, 2274.94 examples/s]
# Preprocessing data... (this takes a little bit, should only happen once per dataset)
# ...

# %%
"""
100 {'eval_exact_match': 46.666666666666664, 'eval_f1': 57.493827160493794}
90 {'eval_exact_match': 54.44444444444444, 'eval_f1': 62.35978835978835}
75 {'eval_exact_match': 61.111111111111114, 'eval_f1': 68.90964590964589}
50 {'eval_exact_match': 61.111111111111114, 'eval_f1': 67.99470899470897}
"""
# Out:
# /content

# %%
# !zip -r /content/timepoint.zip /content/timepoint/
# Out:
#   adding: content/timepoint/ (stored 0%)
#   adding: content/timepoint/checklist50/ (stored 0%)
#   adding: content/timepoint/checklist50/eval_predictions.jsonl (deflated 72%)
#   adding: content/timepoint/checklist50/runs/ (stored 0%)
#   adding: content/timepoint/checklist50/runs/Dec09_08-22-22_da8978f423cb/ (stored 0%)
#   adding: content/timepoint/checklist50/runs/Dec09_08-22-22_da8978f423cb/events.out.tfevents.1702110146.da8978f423cb.64693.0 (deflated 17%)
#   adding: content/timepoint/checklist50/eval_metrics.json (deflated 20%)
#   adding: content/timepoint/checklist90/ (stored 0%)
#   adding: content/timepoint/checklist90/eval_predictions.jsonl (deflated 72%)
#   adding: content/timepoint/checklist90/runs/ (stored 0%)
#   adding: content/timepoint/checklist90/runs/Dec09_08-21-59_da8978f423cb/ (stored 0%)
#   adding: content/timepoint/checklist90/runs/Dec09_08-21-59_da8978f423cb/events.out.tfevents.1702110123.da8978f423cb.64485.0 (deflated 17%)
# ...
